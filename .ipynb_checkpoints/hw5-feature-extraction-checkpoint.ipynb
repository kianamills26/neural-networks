# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = []
with open("archival_data.txt", 'r') as f:
    lines = f.readlines()
  
lines = [line.split() for line in lines]

# Adjust for Color Names
for line in lines:
    if len(line) == 8:
        line[4] = line[4] + " " + line[5]
        line[5] = line[6]
        line[6] = line[7]
        del line[7]

train_df = pd.DataFrame(lines, columns=["name","planet","warp_drive","transponder","surface","axis_ratio", "action"])
print(train_df)
# Out:
#         name      planet warp_drive transponder     surface axis_ratio  \
# 0      Grotz     Klingon        6.9      1006.4       Black        3.5
# 1      Tlarr     Klingon        7.0       994.3       Black        2.3
# 2     Tribok     Klingon        7.3       978.1   Dark Gray        2.8
# 3     Brogut     Klingon        7.1      1005.4   Dark Gray        3.0
# 4     Glorek     Klingon        7.1      1001.8  Light Gray        1.0
# 5      Lorif     Romulan        7.3       980.4   Dark Blue        1.6
# 6     Rallev     Romulan        7.4       977.2  Dark Green        1.8
# 7    Willosh     Romulan        7.3       947.9  Light Gray        1.9
# 8     Loshar     Romulan        7.2       955.8  Light Blue        2.1
# 9     Sarash     Romulan        7.4       960.7  Light Gray        2.3
# 10     A2231    Antarean        6.7      1010.9        Pink        1.2
# 11     E7763    Antarean        6.8      1033.2      Orange        1.2
# ...

# %%
# Plot some graphs to see which features are important
planet = train_df["planet"]
warp = train_df["warp_drive"]
plt.scatter(warp, axis_ratio)
plt.title("Avg. Warp Drive")
plt.show()

transponder = train_df["transponder"]
plt.scatter(transponder, warp)
plt.title("Avg. Transponder Freq")
plt.show()

axis_ratio = train_df["axis_ratio"]
plt.scatter(axis_ratio, transponder)
plt.title("Avg. Axis Ratio")
plt.show()

# %%
# g is the correct output, ie the ship's planet of origin
g = train_df["planet"]

# %%
# How to represent the different ship features in your input vectors
